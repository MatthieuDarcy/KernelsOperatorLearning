# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import pairwise_distances
import numpy as onp
import jax.numpy as np
from jax import jit, vmap
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm as t
from ipywidgets import interact
from jax import grad
from jax.scipy.optimize import minimize
from jax.config import config
config.update("jax_enable_x64", True)
import jax
from jax.scipy.linalg import cholesky, cho_factor, cho_solve
from jax.scipy.optimize import minimize
from jaxopt import ProjectedGradient
from jaxopt.projection import projection_box
import pandas as pd

# %%
PCANet = pd.read_csv("data/PCA_NS.csv", header = None).to_numpy()
DeepONet = pd.read_csv("data/DeepONet_NS.csv", header = None).to_numpy()
Para = pd.read_csv("data/PARA_NS.csv", header = None).to_numpy()
FNO = pd.read_csv("data/FNO_NS.csv", header = None).to_numpy()

np.min(PCANet[:,4]), np.min(FNO[:,4]), np.min(DeepONet[:, 4]), np.min(Para[:, 4])
# Out:
# (DeviceArray(0.02654266, dtype=float64),
#  DeviceArray(0.00259586, dtype=float64),
#  DeviceArray(0.03629472, dtype=float64),
#  DeviceArray(0.04088747, dtype=float64))

# %%
#The columns = [Nexamples, network width, Train, Test]

# %%
Inputs = onp.load('data/NavierStokes_inputs.npy')
Outputs = onp.load('data/NavierStokes_outputs.npy')

# %%
Inputs.shape
# Out:
# (64, 64, 40000)

# %%
Inputs = Inputs.transpose((2,1,0))
Outputs = Outputs.transpose((2,1,0))

Inputs_fl = Inputs.reshape(len(Inputs), 64*64)
Outputs_fl = Outputs.reshape(len(Outputs), 64*64)

# %% [markdown]
# GP regression

# %%
#Jax regression

# %%
def sqeuclidean_distances(x: np.ndarray, y: np.ndarray) -> float:
    return np.sum( (x - y) ** 2)
sqdists = jit(vmap(vmap(sqeuclidean_distances, in_axes=(None, 0)), in_axes=(0, None)))

def euclidean_distances(x: np.ndarray, y: np.ndarray) -> float:
    return np.sqrt(np.sum( (x - y) ** 2))
dists = jit(vmap(vmap(euclidean_distances, in_axes=(None, 0)), in_axes=(0, None)))


@jit
def matern(v1, v2, sigma = 50):
    #V1 is a [k1] vector
    #V2 is a [k2] vector
    #returns a k1xk2 matrix
    d = dists(v1, v2)
    #return a*np.exp(-d**2/sigma)
    return (1+np.sqrt(5)*d/sigma +5*d**2/(3*sigma**2))*np.exp(-np.sqrt(5)*d/sigma)

@jit
def exp(v1, v2, sigma):
    #V1 is a [k1] vector
    #V2 is a [k2] vector
    #returns a k1xk2 matrix
    d = dists(v1, v2)
    return np.exp(-d/sigma)
    #return (1+np.sqrt(5)*d/sigma +5*d**2/(3*sigma**2))*np.exp(-np.sqrt(5)*d/sigma)

@jit
def sqexp(v1, v2, sigma):
    #V1 is a [k1] vector
    #V2 is a [k2] vector
    #returns a k1xk2 matrix
    d = sqdists(v1, v2)
    return np.exp(-d/sigma)
    #return (1+np.sqrt(5)*d/sigma +5*d**2/(3*sigma**2))*np.exp(-np.sqrt(5)*d/sigma)

@jit
def iq(v1, v2, sigma):
    #V1 is a [k1] vector
    #V2 is a [k2] vector
    #returns a k1xk2 matrix
    d = sqdists(v1, v2)
    #return a*np.exp(-d**2/sigma)
    #return (1+np.sqrt(5)*d/sigma +5*d**2/(3*sigma**2))*np.exp(-np.sqrt(5)*d/sigma)
    return 1/np.sqrt(d+sigma)

# %%
Ntrain = 20000
#n_components = 128

# %%
Ytr = Outputs_fl[:Ntrain]
Xtr = Inputs_fl[:Ntrain]
pca = PCA(n_components=128)
Xtr = pca.fit_transform(Xtr)
Xtest = pca.transform(Inputs_fl[20000:])
#Xtest = Inputs_fl[20000:]
Ytest = Outputs_fl[20000:]

# %%
def aux(kernel, s, nugget):
    k = kernel
    Kxx = k(Xtr, Xtr, s)
    nuggeted_matrix = Kxx.at[np.diag_indices_from(Kxx)].add(nugget)
    L = cho_factor(nuggeted_matrix)
    result = cho_solve(L, Ytr)
    Train_pred = Kxx@result #train predictions
    K_te_tr = k(Xtest, Xtr,s)
    Test_pred = K_te_tr@result #test predictions

    np.mean(np.linalg.norm(Ytr-Train_pred, axis = 1))

    aux1 = np.mean(np.linalg.norm(Ytr-Train_pred, axis = 1))
    aux2 = np.mean(np.linalg.norm(Train_pred-Ytr, axis = 1)/np.linalg.norm(Ytr, axis = 1))
    aux3 = np.mean(np.linalg.norm(Ytest-Test_pred, axis = 1))
    aux4 = np.mean(np.linalg.norm(Ytest-Test_pred, axis = 1)/np.linalg.norm(Ytest, axis = 1))
    print(s, nugget)
    print("\n Train error (abs): {0} \n Train error (rel): {1} \n Test error (abs): {2} \n Test error (rel): {3}".format(aux1, aux2, aux3, aux4))
    print('---')

# %%
for kernel in [sqexp]:
    for s in [10]:
        for nugget in [1e-8]:
            aux(kernel, s, nugget)
# Out:
# 10 1e-08
#
#  Train error (abs): 4.960316407446788e-05
#  Train error (rel): 2.096776930638765e-05
#  Test error (abs): 0.0035408267309953575
#  Test error (rel): 0.0013743089405412999
# ---

# %%
for kernel in [sqexp]:
    for s in [10]:
        for nugget in [1e-8]:
            aux(kernel, s, nugget)
# Out:
# 10 1e-08
#
#  Train error (abs): 0.005634811027791851
#  Train error (rel): 0.002468305375670579
#  Test error (abs): 0.14416942014691944
#  Test error (rel): 0.057818634764666255
# ---

# %%
M_to_emulate = sqexp(Xtr[:1000], Xtr[:1000], 10)

# %%
plt.imshow(M_to_emulate)

# %%
#Random features of the gaussian kernel

# %%
Nf = 1000
gaussians = onp.random.normal(size = (Nf, d), scale = sd(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 2>()
#       1 Nf = 1000
# ----> 2 gaussians = onp.random.normal(size = (Nf, d), scale = sd(10))
#
# NameError: name 'd' is not defined

# %%
x_1 = Xtr[23]
x_2 = Xtr[69]

sqexp(np.array([x_1]), np.array([x_2]), 10)

np.exp(-np.dot(x_1-x_2, x_1-x_2)/10),np.mean(np.cos(gaussians@(x_1-x_2)))

# %%
def sd(lengthscale):
    #lengthscale is mine is 2l^2
    return 1/(np.sqrt(lengthscale/2))

# %%
def feature_map(x):
    return np.sqrt(2/Nf)*(np.cos(gaussians@x + indep))
features = jit(vmap(feature_map))

# %%
nugget = 1e-10

# %%
res = []

# %%
d = Xtr.shape[1]

# %%
for Nf in [20000]:
    for l in [10]:
        gaussians = onp.random.normal(size = (Nf, d), scale = sd(l))
        indep = onp.random.uniform(size = Nf)*2*np.pi
        def feature_map(x):
            return np.sqrt(2/Nf)*(np.cos(gaussians@x + indep))
        features = jit(vmap(feature_map))

        Ztr = features(Xtr)
        Zte = features(Xtest)
        Kxx = Ztr.T@Ztr
        nuggeted_matrix = Kxx.at[np.diag_indices_from(Kxx)].add(nugget)
        L = cho_factor(nuggeted_matrix)
        betas= cho_solve(L, Ztr.T@Ytr)
        Train_pred = (Ztr@betas)
        Test_pred = Zte@betas #test predictions
        aux1 = np.mean(np.linalg.norm(Ytr-Train_pred, axis = 1))
        aux2 = np.mean(np.linalg.norm(Train_pred-Ytr, axis = 1)/np.linalg.norm(Ytr, axis = 1))
        aux3 = np.mean(np.linalg.norm(Ytest-Test_pred, axis = 1))
        aux4 = np.mean(np.linalg.norm(Ytest-Test_pred, axis = 1)/np.linalg.norm(Ytest, axis = 1))
        print(Nf)
        print("\n Train error (abs): {0} \n Train error (rel): {1} \n Test error (abs): {2} \n Test error (rel): {3}".format(aux1, aux2, aux3, aux4))
        print('---')
        res.append([Nf, aux4])

# %%
np.array(res).tolist()
